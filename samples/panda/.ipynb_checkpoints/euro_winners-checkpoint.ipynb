# %%
#Ex e 90
import pandas as pd
import re

# %%
#Read the table into a DataFrame
df = pd.read_csv("euro_winners.csv")
df
# Out:
#      Season Nation      Winners    Score           Runners-up Runner-UpNation  \
# 0   1955–56  Spain  Real Madrid      4–3       Stade de Reims          France
# 1   1956–57  Spain  Real Madrid      2–0           Fiorentina           Italy
# 2   1957–58  Spain  Real Madrid      3–2                Milan           Italy
# 3   1958–59  Spain  Real Madrid      2–0       Stade de Reims          France
# 4   1959–60  Spain  Real Madrid      7–3  Eintracht Frankfurt         Germany
# ..      ...    ...          ...      ...                  ...             ...
# 58  2013–14  Spain  Real Madrid      4–1      Atlético Madrid           Spain
# 59  2014–15  Spain    Barcelona      3–1             Juventus           Italy
# 60  2015–16  Spain  Real Madrid  1–1*[L]      Atlético Madrid           Spain
# 61  2016–17  Spain  Real Madrid      4–1             Juventus           Italy
# 62  2017–18  Spain  Real Madrid      3–1            Liverpool         England
#
# ...

# %%
#Define the season column as the index
df = pd.read_csv("euro_winners.csv",index_col='Season')
df
# Out:
#         Nation      Winners    Score           Runners-up Runner-UpNation  \
# Season
# 1955–56  Spain  Real Madrid      4–3       Stade de Reims          France
# 1956–57  Spain  Real Madrid      2–0           Fiorentina           Italy
# 1957–58  Spain  Real Madrid      3–2                Milan           Italy
# 1958–59  Spain  Real Madrid      2–0       Stade de Reims          France
# 1959–60  Spain  Real Madrid      7–3  Eintracht Frankfurt         Germany
# ...        ...          ...      ...                  ...             ...
# 2013–14  Spain  Real Madrid      4–1      Atlético Madrid           Spain
# 2014–15  Spain    Barcelona      3–1             Juventus           Italy
# 2015–16  Spain  Real Madrid  1–1*[L]      Atlético Madrid           Spain
# 2016–17  Spain  Real Madrid      4–1             Juventus           Italy
# 2017–18  Spain  Real Madrid      3–1            Liverpool         England
#
#                                      Venue  Attendance
# Season
# ...

# %%
#Display the last 5 rows of the table
df.tail(5)
# Out:
#         Nation      Winners    Score       Runners-up Runner-UpNation  \
# Season
# 2013–14  Spain  Real Madrid      4–1  Atlético Madrid           Spain
# 2014–15  Spain    Barcelona      3–1         Juventus           Italy
# 2015–16  Spain  Real Madrid  1–1*[L]  Atlético Madrid           Spain
# 2016–17  Spain  Real Madrid      4–1         Juventus           Italy
# 2017–18  Spain  Real Madrid      3–1        Liverpool         England
#
#                                 Venue  Attendance
# Season
# 2013–14        Estádio da Luz, Lisbon       60976
# 2014–15         Olympiastadion,Berlin       70442
# 2015–16                San Siro,Milan       71942
# 2016–17    Millennium Stadium,Cardiff       65842
# 2017–18  NSC Olimpiyskiy Stadium,Kiev       61561

# %%
#Display the name of the team who won the championship at season 2000–01 (note
#the dash in the middle, typed by Alt+0150)
df.loc['2000–01','Winners']
df.at['2000–01','Winners']
# Out:
# 'Bayern Munich'

# %%
#Display the three games with the highest number of attendees
#df[df.Attendance.sort_values(ascending=False).head(3)]

df.sort_values(['Attendance'],ascending=False).head(3)
# Out:
#         Nation      Winners Score           Runners-up Runner-UpNation  \
# Season
# 1959–60  Spain  Real Madrid   7–3  Eintracht Frankfurt         Germany
# 1956–57  Spain  Real Madrid   2–0           Fiorentina           Italy
# 1988–89  Italy        Milan   4–0      Steaua Bucureti         Romania
#
#                                      Venue  Attendance
# Season
# 1959–60               Hampden Park,Glasgow      127621
# 1956–57  Santiago Bernabéu Stadium, Madrid      124000
# 1988–89                 Camp Nou,Barcelona       97000

# %%
d = re.split(r'\-', "1-0") 
d
# Out:
# ['1', '0']

# %%
d = re.split(r'[0-9]\-\%[0-9]', '1-1*[L]') 
d
# Out:
# ['1-1*[L]']

# %%
s = '4-1*[L]'
def get_total(s):
    arr = re.split('\D',s)
    return (int(arr[0]) + int(arr[1]))

get_total(s)
# Out:
# 5

# %%
df['total_s'] = df.Score.apply(get_total)
df.head()
# Out:
#         Nation      Winners Score           Runners-up Runner-UpNation  \
# Season
# 1955–56  Spain  Real Madrid   4–3       Stade de Reims          France
# 1956–57  Spain  Real Madrid   2–0           Fiorentina           Italy
# 1957–58  Spain  Real Madrid   3–2                Milan           Italy
# 1958–59  Spain  Real Madrid   2–0       Stade de Reims          France
# 1959–60  Spain  Real Madrid   7–3  Eintracht Frankfurt         Germany
#
#                                      Venue  Attendance  total_s
# Season
# 1955–56             Parc des Princes,Paris       38239        7
# 1956–57  Santiago Bernabéu Stadium, Madrid      124000        2
# 1957–58            Heysel Stadium,Brussels       67000        5
# 1958–59            Neckarstadion,Stuttgart       72000        2
# 1959–60               Hampden Park,Glasgow      127621       10
