# %% [markdown]
# ![logo](https://dataom.co.il/wp-content/uploads/2019/09/cropped-logo_new-2-100x52.png)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

df = sns.load_dataset('planets')
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# # present a countplot per year,  only for years larger than 2005

# %%
# please use
data = df[df.year>2005]
# palette='cool'

# %% [markdown]
# # present a bar plot for year and number

# %% [markdown]
# # present a scatter plot for distance and mass , identify the colors by the year , use cmap='cool'

# %%
# use plt.plot() to show a line graph for year and orbital_period in yellow color

# %%
#to see only Radial Velocity, please use
data = df[df.method=='Radial Velocity']
