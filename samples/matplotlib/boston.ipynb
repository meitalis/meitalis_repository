# %%
import warnings
warnings.simplefilter('ignore')

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(boston['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
import pandas as pd

# %%
type(boston['data'])
# Out:
# numpy.ndarray

# %%
boston['data'].shape
# Out:
# (506, 13)

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df = pd.DataFrame(data=boston['data'], columns=boston['feature_names'])

# %%
boston['target'].shape
# Out:
# (506,)

# %%
df['MEDV'] = boston['target']

# %%
y = df['MEDV'].copy()
del df['MEDV']
df = pd.concat((y, df), axis=1)

# %%
df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.shape
# Out:
# (506, 14)

# %%
df.dtypes
# Out:
# MEDV       float64
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# MEDV       0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# MEDV     506.0   22.532806    9.197104    5.00000   17.025000   21.20000
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# MEDV       506 non-null float64
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# dtypes: float64(14)
# memory usage: 55.4 KB

# %%
cols = ['RM', 'AGE', 'TAX', 'LSTAT', 'MEDV']

# %%
df[cols].head()
# Out:
#       RM   AGE    TAX  LSTAT  MEDV
# 0  6.575  65.2  296.0   4.98  24.0
# 1  6.421  78.9  242.0   9.14  21.6
# 2  7.185  61.1  242.0   4.03  34.7
# 3  6.998  45.8  222.0   2.94  33.4
# 4  7.147  54.2  222.0   5.33  36.2

# %%
df[cols].corr()
# Out:
#              RM       AGE       TAX     LSTAT      MEDV
# RM     1.000000 -0.240265 -0.292048 -0.613808  0.695360
# AGE   -0.240265  1.000000  0.506456  0.602339 -0.376955
# TAX   -0.292048  0.506456  1.000000  0.543993 -0.468536
# LSTAT -0.613808  0.602339  0.543993  1.000000 -0.737663
# MEDV   0.695360 -0.376955 -0.468536 -0.737663  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
ax = sns.heatmap(df[cols].corr(),
                 cmap=sns.cubehelix_palette(20, light=0.95, dark=0.15), annot=True)
ax.xaxis.tick_top()

# %%
sns.pairplot(df[cols], plot_kws={'alpha': 0.6}, diag_kws={'bins': 30});

# %%
fig, ax = plt.subplots(2, 2)
fig.set_figwidth(10)
fig.set_figheight(8)
sns.regplot('RM', 'MEDV', df, ax=ax[0, 0], scatter_kws={'alpha': 0.4}, color='r')
sns.regplot('LSTAT', 'MEDV', df, ax=ax[0, 1], scatter_kws={'alpha': 0.4}, color='b')
ax[1, 0] = sns.residplot('RM', 'MEDV', df, ax=ax[1, 0], scatter_kws={'alpha': 0.4}, color='r')
ax[1, 0].set_ylabel('MEDV residuals $(y-\hat{y})$')
ax[1, 1] = sns.residplot('LSTAT', 'MEDV', df, ax=ax[1, 1], scatter_kws={'alpha': 0.4}, color='b')
ax[1, 1].set_ylabel('');

# %%
y = df['MEDV'].values
x = df['LSTAT'].values.reshape(-1,1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3)

# %%
x_poly = poly.fit_transform(x)

# %%
x.shape, x_poly.shape
# Out:
# ((506, 1), (506, 4))

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
a_0 = clf.intercept_ + clf.coef_[0]   #intercept
a_1, a_2, a_3 = clf.coef_[1:]         #other coefficients
msg = ('model: y = {:.3f} + {:.3f}x + {:.3f}x^2 + {:.3f}x^3').format(a_0, a_1,  a_2, a_3)
print(msg)
# Out:
# model: y = 48.650 + -3.866x + 0.149x^2 + -0.002x^3

# %%
y_pred = clf.predict(x_poly)
resid_MEDV = y - y_pred

# %%
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y, y_pred)
print('mse = {:.2f}'.format(error))
# Out:
# mse = 28.88

# %%
fig, ax = plt.subplots()
# Plot the samples
ax.scatter(x.flatten(), y, alpha=0.6)
# Plot the polynomial model
x_ = np.linspace(2, 38, 50).reshape(-1, 1)
x_poly = poly.fit_transform(x_)
y_ = clf.predict(x_poly)
ax.plot(x_, y_, color='red', alpha=0.8)
ax.set_xlabel('LSTAT'); ax.set_ylabel('MEDV');

# %%
fig, ax = plt.subplots(figsize=(5, 7))
ax.scatter(x, resid_MEDV, alpha=0.6)
ax.set_xlabel('LSTAT')
ax.set_ylabel('MEDV Residual $(y-\hat{y})$')    
plt.axhline(0, color='black', ls='dotted');

# %%
sns.distplot(df.AGE.values, bins=100, hist_kws={'cumulative': True}, kde_kws={'lw': 0})
plt.xlabel('AGE')
plt.ylabel('CDF')
plt.axhline(0.33, color='red')
plt.axhline(0.66, color='red')
plt.xlim(0, df.AGE.max());

# %%
def get_age_category(x):
    if x < 50:
        return 'Relatively New'
    elif 50 <= x < 85:
        return 'Relatively Old'
    else:
        return 'Very Old'

df['AGE_category'] = df.AGE.apply(get_age_category)

# %%
sns.violinplot(x='MEDV', y='AGE_category', data=df, order=['Relatively New', 'Relatively Old', 'Very Old']);

# %%
sns.violinplot(x='MEDV', y='AGE_category', data=df, order=['Relatively New', 'Relatively Old', 'Very Old'], inner='point');

# %%
sns.pairplot(df[cols], plot_kws={'alpha': 0.6}, diag_kws={'bins': 30});

# %%
cols = ['RM', 'AGE', 'TAX', 'LSTAT', 'MEDV', 'AGE_category']
sns.pairplot(df[cols], plot_kws={'alpha': 0.5}, diag_kind='hist', diag_kws={'bins': 30, 'alpha': 0.5},  hue='AGE_category', 
             hue_order=['Relatively New', 'Relatively Old', 'Very Old']);
