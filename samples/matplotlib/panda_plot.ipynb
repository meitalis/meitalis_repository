# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

#randn = -1 > x < 1
# ser = pd.Series(np.random.randn(10).cumsum(),
#                index=np.arange(0,100,10))

# ser.plot(title="Random walk")

# ser.plot(title="Random walk",style='-ok')

# ax = ser.plot(title="Random walk",style='-ok',figsize=(7,5))
# ax.set_xlabel('x')
# ax.set_xlabel('y')


# df = pd.DataFrame(np.random.randn(10,4).cumsum(axis=0),
#                     columns = ['A','B','C','D'],
#                     index=np.arange(0,100,10))
# ax = df.plot()

# df = pd.DataFrame(np.random.randn(10,4).cumsum(axis=0),
#                     columns = ['A','B','C','D'],
#                     index=np.arange(0,100,10))
# ax = df.plot(subplots=True)
# type(ax[0].set_title('AAAA'))


fig,axes = plt.subplots(12,2)
data = pd.Series(np.random.rand(8), index=list('abcdefgh'))
data.plot.bar(ax=axes[0][0], color='r',alpha=0.7)
data.plot.barh(ax=axes[1][1], color='g',alpha=0.9)

# %%
df = pd.DataFrame(np.random.rand(6,4),
                     columns = ['A','B','C','D'],
                     index = ['one','two','three','four','five','six'])
df
# Out:
#               A         B         C         D
# one    0.911549  0.735395  0.651554  0.749170
# two    0.086193  0.631089  0.828441  0.077255
# three  0.559388  0.512534  0.775764  0.216502
# four   0.243997  0.593351  0.932881  0.995434
# five   0.042935  0.097155  0.724729  0.963792
# six    0.948237  0.564026  0.385800  0.991719

# %%
df.plot.barh(stacked=False,alpha=0.5)
df.plot.bar(stacked=True)

# %%
from pandas.plotting import scatter_matrix

df = pd.DataFrame(np.random.randn(10000,4),
                 columns=['a','b','c','d'])
_=scatter_matrix(df,alpha=0.5,figsize=(6,6),diagonal='hist')

# %%
from pandas.plotting import scatter_matrix

df = pd.DataFrame(np.random.rand(10000,4),
                 columns=['a','b','c','d'])
_=scatter_matrix(df,alpha=0.5,figsize=(6,6),diagonal='hist')
